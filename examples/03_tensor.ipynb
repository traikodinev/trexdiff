# %%
import trexdiff

# %%
import numpy as np

# %%
M, N, K = 3, 4, 5
t1 = trexdiff.tensor2d(arr1 := np.random.rand(M, N))
t2 = trexdiff.tensor2d(arr2 := np.random.rand(N, K))

# %%
t1
# Out:
# tensor2d([
#   [0.58, 0.91, 0.77, 0.15],
#   [0.91, 0.90, 0.42, 0.85],
#   [0.71, 0.52, 0.57, 0.66]
# ])

# %%
t1 @ t2
# Out:
# tensor2d([
#   [1.18, 1.09, 0.96, 1.73, 0.76],
#   [1.80, 1.65, 1.22, 2.08, 1.11],
#   [1.53, 1.45, 0.98, 1.64, 0.82]
# ])
